# %%
# cv2.imread('/content/data/frame0.jpg')
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
import cv2 
st='chessboard.png'
img = cv2.imread(st)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=292x209 at 0x7F63112C22B0>

# %%
img_copy = np.copy(img)
img_copy = cv2.cvtColor(img_copy, cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(img_copy, cv2.COLOR_RGB2GRAY)
gray = np.float32(gray)
dst = cv2.cornerHarris(gray, 2, 3, 0.04)

dst = cv2.dilate(dst, None)


cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=L size=292x209 at 0x7F6311300C88>

# %%
threshold = 0.1*dst.max()
for j in range(0,dst.shape[0]):
  for i in range(0, dst.shape[1]):
    if(dst[j,i] > threshold):
      cv2.circle(img_copy,(i,j), 1, (0,0,255), 1)
cv2_imshow(img_copy)
# Out:
# <PIL.Image.Image image mode=RGB size=292x209 at 0x7F63111DD160>
